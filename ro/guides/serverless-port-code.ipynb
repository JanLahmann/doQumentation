# %%
# Install required packages (auto-skipped if already installed)
import importlib
if importlib.util.find_spec('qiskit') is None:
    # !pip install -q qiskit qiskit-aer qiskit-ibm-runtime pylatexenc
else:
    print("\u2713 Packages already installed")

# To run on real quantum hardware, uncomment and fill in your credentials:
# from qiskit_ibm_runtime import QiskitRuntimeService
# QiskitRuntimeService.save_account(
#     token="<your-api-key>",
#     instance="<your-crn>",
#     overwrite=True
# )

# %% [markdown]
# # Portează codul în Qiskit Serverless
#
# import Tabs from '@theme/Tabs';
# import TabItem from '@theme/TabItem';
#
#
#
# Următorul exemplu demonstrează cum să portezi codul existent pentru a beneficia de Qiskit Serverless.
# > **Note:** Codul următor presupune că ai salvat deja acreditările. Dacă nu ai făcut asta, urmează instrucțiunile din [Configurează-ți contul IBM Cloud](/guides/cloud-setup-untrusted) pentru a te autentifica cu cheia ta API.
#
# ## Actualizează experimentul
# <Tabs>
#   <TabItem value="LocalExperiment" label="Experiment local">
