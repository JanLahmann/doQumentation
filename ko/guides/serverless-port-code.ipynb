# %%
# Install required packages (auto-skipped if already installed)
import importlib
if importlib.util.find_spec('qiskit') is None:
    # !pip install -q qiskit qiskit-aer qiskit-ibm-runtime pylatexenc
else:
    print("\u2713 Packages already installed")

# To run on real quantum hardware, uncomment and fill in your credentials:
# from qiskit_ibm_runtime import QiskitRuntimeService
# QiskitRuntimeService.save_account(
#     token="<your-api-key>",
#     instance="<your-crn>",
#     overwrite=True
# )

# %% [markdown]
# # Qiskit Serverless로 코드 이식하기
#
# import Tabs from '@theme/Tabs';
# import TabItem from '@theme/TabItem';
#
#
#
# 다음 예시는 Qiskit Serverless를 활용하기 위해 기존 코드를 이식하는 방법을 보여줍니다.
# > **Note:** 다음 코드는 자격 증명이 저장되어 있다고 가정합니다. 저장하지 않으셨다면, [IBM Cloud 계정 설정](/guides/cloud-setup-untrusted) 페이지의 지침에 따라 API 키로 인증하세요.
#
# ## 실험 업데이트
# <Tabs>
#   <TabItem value="LocalExperiment" label="로컬 실험">
