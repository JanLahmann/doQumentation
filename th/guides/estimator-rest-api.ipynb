# %%
# Install required packages (auto-skipped if already installed)
import importlib
if importlib.util.find_spec('qiskit') is None:
    # !pip install -q qiskit qiskit-aer qiskit-ibm-runtime pylatexenc
else:
    print("\u2713 Packages already installed")

# To run on real quantum hardware, uncomment and fill in your credentials:
# from qiskit_ibm_runtime import QiskitRuntimeService
# QiskitRuntimeService.save_account(
#     channel="ibm_quantum_platform",
#     token="<your-api-key>",
#     # instance="<IBM Cloud CRN or instance name>",  # optional
#     set_as_default=True,
#     overwrite=True,
# )

# %% [markdown]
# <details>
# <summary><b>Package versions</b></summary>
#
# โค้ดในหน้านี้พัฒนาโดยใช้ requirements ต่อไปนี้
# เราแนะนำให้ใช้เวอร์ชันเหล่านี้หรือใหม่กว่า
#
# ```
# qiskit[all]~=2.3.0
# ```
# </details>
# ขั้นตอนในหัวข้อนี้อธิบายวิธีรันและกำหนดค่า workload ด้วย REST API และแสดงตัวอย่างการเรียกใช้งานในโปรแกรมใดก็ได้ที่ต้องการ
#
# > **Note:** เอกสารนี้ใช้ Python module `requests` เพื่อสาธิต Qiskit Runtime REST API อย่างไรก็ตาม workflow นี้สามารถรันโดยใช้ภาษาหรือ framework ใดก็ได้ที่รองรับการทำงานกับ REST API ดูรายละเอียดได้ใน [เอกสาร API reference](https://docs.quantum.ibm.com/api/qiskit-ibm-runtime/tags/jobs)

# %% [markdown]
# ## 1. เริ่มต้นบัญชี
#
# เนื่องจาก Qiskit Runtime Estimator เป็นบริการแบบ managed จึงต้องเริ่มต้นบัญชีก่อน จากนั้นเลือกอุปกรณ์ที่ต้องการใช้คำนวณ expectation value
#
# ดูรายละเอียดวิธีเริ่มต้นบัญชี ดู Backend ที่มี และยกเลิก token ได้ที่ [หัวข้อนี้](/guides/cloud-setup-rest-api)

# %% [markdown]
# ## 2. สร้าง QASM circuit
#
# ต้องมี circuit อย่างน้อยหนึ่งตัวเป็น input ให้ Estimator primitive
#
# นิยาม QASM quantum circuit ตัวอย่างเช่น:
